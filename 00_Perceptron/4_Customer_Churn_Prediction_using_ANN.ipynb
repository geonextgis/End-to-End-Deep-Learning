# %% [markdown]
# # **Customer Churn Prediction using ANN**

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/bank-customer-churn-prediction/Churn_Modelling.csv

# %% [markdown]
# ## **Import Required Libraries**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

sns.set_style("whitegrid")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## **Read the Data**

# %%
df = pd.read_csv("/kaggle/input/bank-customer-churn-prediction/Churn_Modelling.csv")
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
# Check the shape of the dataframe
df.shape
# Out:
# (10000, 14)

# %% [markdown]
# ## **Data Preprocessing**

# %%
# Check for the missing values
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
# Check the information of all the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# Drop the irrelevant columns
df.drop(columns=["RowNumber", "CustomerId", "Surname"], inplace=True)
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
# Check for the duplicated rows
df.duplicated().sum()
# Out:
# 0

# %%
# Check the number of people who Exited
df["Exited"].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
# Plot the categorical variables
sns.countplot(x=df["Gender"])
plt.show()

# %%
sns.countplot(x=df["Geography"])
plt.show()

# %%
# Apply One Hot Encoding on Categorical columns
df = pd.get_dummies(df, columns=["Geography", "Gender"], drop_first=True, dtype=int)
df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0               1        101348.88       1                  0
# 1               1        112542.58       0                  0
# 2               0        113931.57       1                  0
# 3               0         93826.63       0                  0
# 4               1         79084.10       0                  0
#
#    Geography_Spain  Gender_Male
# 0                0            0
# 1                1            0
# 2                0            0
# 3                0            0
# 4                1            0

# %% [markdown]
# ## **Train Test Split**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop("Exited", axis=1),
                                                    df["Exited"],
                                                    test_size=0.2,
                                                    random_state=0)
X_train.shape, X_test.shape
# Out:
# ((8000, 11), (2000, 11))

# %% [markdown]
# ## **Feature Scaling**

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Create an object of the StandardScaler class
scaler = StandardScaler()

# Fit the training data
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 0.16958176, -0.46460796,  0.00666099, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-2.30455945,  0.30102557, -1.37744033, ...,  1.75486502,
#         -0.57369368,  0.91601335],
#        [-1.19119591, -0.94312892, -1.031415  , ..., -0.5698444 ,
#         -0.57369368, -1.09168714],
#        ...,
#        [ 0.9015152 , -0.36890377,  0.00666099, ..., -0.5698444 ,
#         -0.57369368,  0.91601335],
#        [-0.62420521, -0.08179119,  1.39076231, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-0.28401079,  0.87525072, -1.37744033, ...,  1.75486502,
#         -0.57369368, -1.09168714]])

# %% [markdown]
# ## **Build an Artifical Neural Network**

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
# Instantiate a Sequential model
model = Sequential()

# Add two Dense layer with 11 nodes into the Sequential Model
model.add(Dense(11, activation="relu", input_dim=11))
model.add(Dense(11, activation="relu"))

# Add another layer for the output with a single node
model.add(Dense(1, activation="sigmoid"))

# %%
# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 11)                132
#
#  dense_1 (Dense)             (None, 11)                132
#
#  dense_2 (Dense)             (None, 1)                 12
#
# =================================================================
# Total params: 276
# Trainable params: 276
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(loss="binary_crossentropy", optimizer="Adam", metrics=["accuracy"])

# %%
# Fit the training data
history = model.fit(X_train_scaled, y_train, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 200/200 [==============================] - 6s 4ms/step - loss: 0.5232 - accuracy: 0.7845 - val_loss: 0.4668 - val_accuracy: 0.7969
# Epoch 2/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4527 - accuracy: 0.7958 - val_loss: 0.4489 - val_accuracy: 0.7969
# Epoch 3/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4403 - accuracy: 0.7958 - val_loss: 0.4417 - val_accuracy: 0.7969
# Epoch 4/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4331 - accuracy: 0.7958 - val_loss: 0.4363 - val_accuracy: 0.7969
# Epoch 5/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4280 - accuracy: 0.7966 - val_loss: 0.4319 - val_accuracy: 0.8062
# Epoch 6/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4237 - accuracy: 0.8047 - val_loss: 0.4272 - val_accuracy: 0.8144
# Epoch 7/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4186 - accuracy: 0.8152 - val_loss: 0.4226 - val_accuracy: 0.8175
# Epoch 8/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4137 - accuracy: 0.8211 - val_loss: 0.4166 - val_accuracy: 0.8231
# Epoch 9/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4052 - accuracy: 0.8303 - val_loss: 0.4083 - val_accuracy: 0.8275
# Epoch 10/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3953 - accuracy: 0.8345 - val_loss: 0.4004 - val_accuracy: 0.8300
# Epoch 11/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3867 - accuracy: 0.8394 - val_loss: 0.3931 - val_accuracy: 0.8400
# Epoch 12/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3777 - accuracy: 0.8448 - val_loss: 0.3870 - val_accuracy: 0.8406
# Epoch 13/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3701 - accuracy: 0.8466 - val_loss: 0.3802 - val_accuracy: 0.8413
# Epoch 14/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3634 - accuracy: 0.8511 - val_loss: 0.3746 - val_accuracy: 0.8456
# Epoch 15/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3580 - accuracy: 0.8555 - val_loss: 0.3695 - val_accuracy: 0.8494
# Epoch 16/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3529 - accuracy: 0.8553 - val_loss: 0.3674 - val_accuracy: 0.8481
# Epoch 17/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3493 - accuracy: 0.8580 - val_loss: 0.3645 - val_accuracy: 0.8512
# Epoch 18/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3461 - accuracy: 0.8583 - val_loss: 0.3627 - val_accuracy: 0.8544
# Epoch 19/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3437 - accuracy: 0.8609 - val_loss: 0.3640 - val_accuracy: 0.8544
# Epoch 20/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3421 - accuracy: 0.8597 - val_loss: 0.3613 - val_accuracy: 0.8562
# Epoch 21/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3410 - accuracy: 0.8598 - val_loss: 0.3604 - val_accuracy: 0.8525
# Epoch 22/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3393 - accuracy: 0.8605 - val_loss: 0.3596 - val_accuracy: 0.8562
# Epoch 23/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3379 - accuracy: 0.8611 - val_loss: 0.3593 - val_accuracy: 0.8556
# Epoch 24/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3376 - accuracy: 0.8600 - val_loss: 0.3579 - val_accuracy: 0.8600
# Epoch 25/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3367 - accuracy: 0.8617 - val_loss: 0.3563 - val_accuracy: 0.8600
# Epoch 26/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3360 - accuracy: 0.8627 - val_loss: 0.3559 - val_accuracy: 0.8606
# Epoch 27/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3347 - accuracy: 0.8608 - val_loss: 0.3553 - val_accuracy: 0.8575
# Epoch 28/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3342 - accuracy: 0.8623 - val_loss: 0.3545 - val_accuracy: 0.8612
# Epoch 29/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3340 - accuracy: 0.8617 - val_loss: 0.3542 - val_accuracy: 0.8569
# Epoch 30/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3332 - accuracy: 0.8655 - val_loss: 0.3533 - val_accuracy: 0.8600
# Epoch 31/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3330 - accuracy: 0.8631 - val_loss: 0.3531 - val_accuracy: 0.8594
# Epoch 32/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3317 - accuracy: 0.8645 - val_loss: 0.3537 - val_accuracy: 0.8562
# Epoch 33/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3315 - accuracy: 0.8636 - val_loss: 0.3527 - val_accuracy: 0.8587
# Epoch 34/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3316 - accuracy: 0.8630 - val_loss: 0.3509 - val_accuracy: 0.8575
# Epoch 35/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3307 - accuracy: 0.8642 - val_loss: 0.3517 - val_accuracy: 0.8575
# Epoch 36/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3302 - accuracy: 0.8634 - val_loss: 0.3513 - val_accuracy: 0.8556
# Epoch 37/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3299 - accuracy: 0.8652 - val_loss: 0.3504 - val_accuracy: 0.8581
# Epoch 38/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3294 - accuracy: 0.8625 - val_loss: 0.3504 - val_accuracy: 0.8587
# Epoch 39/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3292 - accuracy: 0.8633 - val_loss: 0.3504 - val_accuracy: 0.8556
# Epoch 40/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3285 - accuracy: 0.8653 - val_loss: 0.3496 - val_accuracy: 0.8612
# Epoch 41/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3285 - accuracy: 0.8637 - val_loss: 0.3495 - val_accuracy: 0.8600
# Epoch 42/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3280 - accuracy: 0.8644 - val_loss: 0.3492 - val_accuracy: 0.8606
# Epoch 43/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3283 - accuracy: 0.8639 - val_loss: 0.3496 - val_accuracy: 0.8550
# Epoch 44/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3273 - accuracy: 0.8652 - val_loss: 0.3507 - val_accuracy: 0.8569
# Epoch 45/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3278 - accuracy: 0.8628 - val_loss: 0.3500 - val_accuracy: 0.8569
# Epoch 46/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3263 - accuracy: 0.8652 - val_loss: 0.3498 - val_accuracy: 0.8581
# Epoch 47/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3267 - accuracy: 0.8639 - val_loss: 0.3490 - val_accuracy: 0.8569
# Epoch 48/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3264 - accuracy: 0.8639 - val_loss: 0.3498 - val_accuracy: 0.8575
# Epoch 49/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3253 - accuracy: 0.8645 - val_loss: 0.3488 - val_accuracy: 0.8575
# Epoch 50/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3255 - accuracy: 0.8670 - val_loss: 0.3500 - val_accuracy: 0.8562
# Epoch 51/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3249 - accuracy: 0.8650 - val_loss: 0.3547 - val_accuracy: 0.8544
# Epoch 52/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3256 - accuracy: 0.8666 - val_loss: 0.3490 - val_accuracy: 0.8581
# Epoch 53/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3250 - accuracy: 0.8662 - val_loss: 0.3486 - val_accuracy: 0.8612
# Epoch 54/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3244 - accuracy: 0.8647 - val_loss: 0.3502 - val_accuracy: 0.8556
# Epoch 55/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3245 - accuracy: 0.8655 - val_loss: 0.3499 - val_accuracy: 0.8575
# Epoch 56/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3242 - accuracy: 0.8645 - val_loss: 0.3485 - val_accuracy: 0.8594
# Epoch 57/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3242 - accuracy: 0.8650 - val_loss: 0.3506 - val_accuracy: 0.8569
# Epoch 58/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3237 - accuracy: 0.8675 - val_loss: 0.3506 - val_accuracy: 0.8606
# Epoch 59/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3237 - accuracy: 0.8662 - val_loss: 0.3484 - val_accuracy: 0.8581
# Epoch 60/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3235 - accuracy: 0.8666 - val_loss: 0.3487 - val_accuracy: 0.8600
# Epoch 61/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3235 - accuracy: 0.8662 - val_loss: 0.3490 - val_accuracy: 0.8612
# Epoch 62/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3230 - accuracy: 0.8673 - val_loss: 0.3499 - val_accuracy: 0.8600
# Epoch 63/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3232 - accuracy: 0.8670 - val_loss: 0.3495 - val_accuracy: 0.8644
# Epoch 64/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3225 - accuracy: 0.8655 - val_loss: 0.3493 - val_accuracy: 0.8581
# Epoch 65/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3229 - accuracy: 0.8669 - val_loss: 0.3496 - val_accuracy: 0.8575
# Epoch 66/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3224 - accuracy: 0.8675 - val_loss: 0.3510 - val_accuracy: 0.8594
# Epoch 67/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3223 - accuracy: 0.8650 - val_loss: 0.3500 - val_accuracy: 0.8581
# Epoch 68/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3232 - accuracy: 0.8662 - val_loss: 0.3512 - val_accuracy: 0.8594
# Epoch 69/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3221 - accuracy: 0.8678 - val_loss: 0.3506 - val_accuracy: 0.8587
# Epoch 70/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3229 - accuracy: 0.8673 - val_loss: 0.3517 - val_accuracy: 0.8594
# Epoch 71/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3221 - accuracy: 0.8670 - val_loss: 0.3507 - val_accuracy: 0.8612
# Epoch 72/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3216 - accuracy: 0.8658 - val_loss: 0.3524 - val_accuracy: 0.8587
# Epoch 73/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3217 - accuracy: 0.8669 - val_loss: 0.3500 - val_accuracy: 0.8612
# Epoch 74/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3217 - accuracy: 0.8648 - val_loss: 0.3512 - val_accuracy: 0.8581
# Epoch 75/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3217 - accuracy: 0.8672 - val_loss: 0.3510 - val_accuracy: 0.8606
# Epoch 76/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3217 - accuracy: 0.8659 - val_loss: 0.3511 - val_accuracy: 0.8606
# Epoch 77/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3217 - accuracy: 0.8659 - val_loss: 0.3493 - val_accuracy: 0.8612
# Epoch 78/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3210 - accuracy: 0.8687 - val_loss: 0.3502 - val_accuracy: 0.8594
# Epoch 79/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3210 - accuracy: 0.8670 - val_loss: 0.3502 - val_accuracy: 0.8594
# Epoch 80/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3212 - accuracy: 0.8669 - val_loss: 0.3516 - val_accuracy: 0.8606
# Epoch 81/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3212 - accuracy: 0.8677 - val_loss: 0.3505 - val_accuracy: 0.8600
# Epoch 82/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3210 - accuracy: 0.8678 - val_loss: 0.3508 - val_accuracy: 0.8587
# Epoch 83/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3204 - accuracy: 0.8672 - val_loss: 0.3512 - val_accuracy: 0.8600
# Epoch 84/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3202 - accuracy: 0.8673 - val_loss: 0.3507 - val_accuracy: 0.8606
# Epoch 85/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3207 - accuracy: 0.8662 - val_loss: 0.3511 - val_accuracy: 0.8600
# Epoch 86/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3207 - accuracy: 0.8653 - val_loss: 0.3502 - val_accuracy: 0.8612
# Epoch 87/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3201 - accuracy: 0.8675 - val_loss: 0.3517 - val_accuracy: 0.8594
# Epoch 88/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3203 - accuracy: 0.8669 - val_loss: 0.3500 - val_accuracy: 0.8612
# Epoch 89/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3203 - accuracy: 0.8670 - val_loss: 0.3522 - val_accuracy: 0.8612
# Epoch 90/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3204 - accuracy: 0.8677 - val_loss: 0.3498 - val_accuracy: 0.8600
# Epoch 91/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3206 - accuracy: 0.8681 - val_loss: 0.3502 - val_accuracy: 0.8587
# Epoch 92/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3199 - accuracy: 0.8659 - val_loss: 0.3504 - val_accuracy: 0.8619
# Epoch 93/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3203 - accuracy: 0.8697 - val_loss: 0.3501 - val_accuracy: 0.8619
# Epoch 94/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3204 - accuracy: 0.8680 - val_loss: 0.3502 - val_accuracy: 0.8619
# Epoch 95/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3202 - accuracy: 0.8675 - val_loss: 0.3510 - val_accuracy: 0.8600
# Epoch 96/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3203 - accuracy: 0.8666 - val_loss: 0.3514 - val_accuracy: 0.8594
# Epoch 97/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3201 - accuracy: 0.8672 - val_loss: 0.3510 - val_accuracy: 0.8606
# Epoch 98/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3201 - accuracy: 0.8683 - val_loss: 0.3505 - val_accuracy: 0.8612
# Epoch 99/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3196 - accuracy: 0.8678 - val_loss: 0.3511 - val_accuracy: 0.8600
# Epoch 100/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3198 - accuracy: 0.8681 - val_loss: 0.3532 - val_accuracy: 0.8612

# %%
# Check all 132 weights of the first layer
model.layers[0].get_weights()[0]
# Out:
# array([[-0.2201297 , -0.2561814 , -0.06925394,  0.20761363,  0.28628358,
#          0.04310253,  0.07334142,  0.09160335, -0.04909608,  0.12110082,
#         -0.07761919],
#        [ 0.94942856, -0.88033396, -0.2532562 ,  0.30340934, -0.47571146,
#         -0.23202303,  0.13324459,  0.4249229 , -0.79431355,  0.49216118,
#         -0.4669855 ],
#        [-0.18972132, -0.1624947 , -0.05784958,  0.17031173, -0.23392388,
#          0.01977917,  0.00389929,  0.00926839,  0.00483385,  0.13334826,
#         -0.06395531],
#        [-0.2642813 ,  0.09607118, -0.31413198, -0.9318075 ,  0.23275127,
#         -0.23956077, -0.16304658, -0.02548202,  0.12010734,  0.42493188,
#         -0.19461185],
#        [-0.52671105, -0.13551553, -0.20574954, -0.5222244 , -0.05002894,
#         -0.29467627, -1.2931043 ,  0.96495724, -0.26200897, -0.3488732 ,
#         -0.3184586 ],
#        [-0.23318867,  0.0843712 ,  0.08495087,  0.11545004, -0.18774858,
#         -0.13801534,  0.07076009,  0.03904931,  0.109185  ,  0.42128995,
#          0.08401   ],
#        [ 0.43783712,  0.29580244,  0.16922967, -0.04100962, -0.5457182 ,
#          0.22862355, -0.17436552, -0.35511485, -0.40992525,  0.5533178 ,
#          0.2767978 ],
#        [ 0.2201579 , -0.46841356,  0.06675677, -0.02919545,  0.3332011 ,
#          0.2213795 ,  0.25028148,  0.31669217,  0.08781653,  0.36124736,
#         -0.17856467],
#        [-0.01835796, -0.3043151 , -0.09199546, -0.2539029 , -0.1188433 ,
#         -0.31516647,  0.09712561, -0.13888168,  0.12812376,  0.26988676,
#         -0.44027254],
#        [-0.3263768 , -0.02229436, -1.0652016 ,  0.29399785, -0.37625897,
#         -0.13301243,  0.09173811,  0.28697208,  0.21302064,  0.31468335,
#          0.48350853],
#        [ 0.13232858, -0.33953145,  0.10709831,  0.023025  , -0.41747722,
#          0.74185175,  0.0191017 , -0.07867822,  0.0313441 ,  0.00150611,
#         -0.4234927 ]], dtype=float32)

# %%
# Check all the weights of the second layer
model.layers[1].get_weights()
# Out:
# [array([[-5.27164042e-01, -9.45597440e-02,  3.10227156e-01,
#           1.33840427e-01, -5.99915385e-01, -4.90191609e-01,
#          -9.10486758e-01, -5.64238071e-01, -7.37893462e-01,
#           7.56060243e-01,  2.76632130e-01],
#         [-6.35056317e-01,  1.45510882e-01,  1.49532050e-01,
#           8.09053630e-02,  1.76078796e-01, -7.22699333e-04,
#           3.59074235e-01, -3.59594285e-01, -4.65714961e-01,
#           4.82038036e-02, -1.05583918e+00],
#         [ 5.71410179e-01, -1.84961572e-01,  8.33427757e-02,
#           1.10661224e-01,  3.51531446e-01,  4.42042410e-01,
#          -6.06605932e-02,  2.40314782e-01,  3.31868589e-01,
#          -3.70255232e-01, -4.79995340e-01],
#         [ 1.80674404e-01, -4.70571399e-01, -3.68171781e-02,
#           7.60213673e-01, -2.42827594e-01, -3.83281261e-02,
#          -7.62662739e-02, -4.21827406e-01, -1.65960595e-01,
#           4.59727466e-01,  5.30085742e-01],
#         [ 4.86092895e-01, -3.22111040e-01, -8.92930776e-02,
#          -4.41085964e-01, -6.19164765e-01,  1.97141618e-01,
#          -2.97558874e-01, -5.79427779e-01, -4.63043720e-01,
#          -5.09526253e-01,  1.31911486e-01],
#         [ 2.51357615e-01, -3.95511776e-01, -1.25155732e-01,
#           3.55522968e-02,  1.14217304e-01, -2.31224313e-01,
#           4.56031173e-01,  3.58872622e-01,  7.41349220e-01,
#          -5.47056258e-01,  4.89198089e-01],
#         [-6.45565629e-01,  8.70990872e-01, -4.94742364e-01,
#           5.96011221e-01,  2.84714580e-01, -3.52797896e-01,
#           3.89459729e-02,  2.22753629e-01, -4.38258015e-02,
#          -9.49966431e-01, -7.81141222e-01],
#         [-1.84531108e-01,  1.02707553e+00, -1.87680330e-02,
#          -2.23888963e-01, -4.06305164e-01, -2.05742627e-01,
#           4.02055122e-02,  2.31654029e-02,  9.41084996e-02,
#          -1.11269079e-01, -2.79297237e-03],
#         [-1.25100628e-01, -3.88325334e-01, -1.52397722e-01,
#          -1.72640353e-01,  1.66688994e-01, -7.04111680e-02,
#           9.10855457e-02, -5.01079336e-02, -2.30768591e-01,
#           7.59199023e-01,  4.17963773e-01],
#         [-9.38590914e-02, -2.54045457e-01, -4.80883896e-01,
#          -8.75778615e-01, -4.96273994e-01,  1.89793020e-01,
#          -1.12656556e-01, -2.61602461e-01, -4.32458580e-01,
#           3.12156469e-01,  4.90394264e-01],
#         [ 7.66881406e-02, -2.93621242e-01,  3.10779452e-01,
#           1.22473747e-01,  6.40982270e-01,  3.51995528e-01,
#           2.23684266e-01,  5.70795178e-01,  3.66160899e-01,
#          -1.81497976e-01, -1.44214764e-01]], dtype=float32),
#  array([ 0.6052516 ,  0.60846967,  0.5345434 , -0.5034535 ,  0.29780337,
#          0.54900324,  0.50290984,  0.16909881,  0.372073  ,  0.02547452,
#          0.37364802], dtype=float32)]

# %%
# Check all the weights of the last layer
model.layers[2].get_weights()
# Out:
# [array([[-0.7098882 ],
#         [ 1.5098363 ],
#         [-0.8408857 ],
#         [ 1.0782173 ],
#         [-0.2521104 ],
#         [-0.69690955],
#         [-0.49316746],
#         [-0.48142573],
#         [-0.53976524],
#         [-1.0892011 ],
#         [-0.9612555 ]], dtype=float32),
#  array([0.26346537], dtype=float32)]

# %% [markdown]
# ## **Predict the Test Data**

# %%
y_pred = model.predict(X_test_scaled)
y_pred
# Out:
# 63/63 [==============================] - 0s 1ms/step
# array([[0.26413718],
#        [0.2086768 ],
#        [0.06008315],
#        ...,
#        [0.15121657],
#        [0.25462443],
#        [0.17219877]], dtype=float32)

# %%
# Convert the predicted probability into binary classes
# Assume a threshold value
threshold = 0.5

y_pred = np.where(y_pred > threshold, 1, 0)
y_pred
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]])

# %% [markdown]
# ## **Accuracy Assessment**

# %%
from sklearn.metrics import accuracy_score

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8585

# %% [markdown]
# ## **Plot the Training and Validation Loss**

# %%
# Print the key names of the history dictionary
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.plot(history.history["accuracy"], label="Training Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
